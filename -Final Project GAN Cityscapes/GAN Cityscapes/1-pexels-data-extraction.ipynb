# %% [markdown]
# <img src="https://www.screnter.com/wp-content/uploads/2021/01/pexels-logo.jpg" alt="drawing" width="300"/>
#
# # Pexels Data Extraction

# %% [markdown]
# ## 1. Connect to Google Drive Folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/CS Courses/CS156/Assignments/Final')

# %% [markdown]
# ## 2. Check number of files in image folder

# %%
from glob import glob
len(glob("cityscapes/*"))
# Out:
# 7983

# %% [markdown]
# ## 3. Data Extraction using the Scraper

# %%
# !python pexels_scraper.py -k "563492ad6f91700001000001537b70e87e204efcb04961323e78fd5c" -c "cityscape" -d "cityscapes" -p 10 40 80
# Out:
# >> Page 10 out of 40 complete.
# >> Page 11 out of 40 complete.
# >> Page 12 out of 40 complete.
# >> Page 13 out of 40 complete.
# >> Page 14 out of 40 complete.
# >> Page 15 out of 40 complete.
# >> Page 16 out of 40 complete.
# >> Page 17 out of 40 complete.
# >> Page 18 out of 40 complete.
# >> Page 19 out of 40 complete.
# >> Page 20 out of 40 complete.
# >> Page 21 out of 40 complete.
# >> Page 22 out of 40 complete.
# >> Page 23 out of 40 complete.
# >> Page 24 out of 40 complete.
# >> Page 25 out of 40 complete.
# >> Page 26 out of 40 complete.
# >> Page 27 out of 40 complete.
# >> Page 28 out of 40 complete.
# >> Page 29 out of 40 complete.
# >> Page 30 out of 40 complete.
# >> Page 31 out of 40 complete.
# >> Page 32 out of 40 complete.
# >> Page 33 out of 40 complete.
# >> Page 34 out of 40 complete.
# >> Page 35 out of 40 complete.
# >> Page 36 out of 40 complete.
# >> Page 37 out of 40 complete.
# >> Page 38 out of 40 complete.
# >> Page 39 out of 40 complete.
# ...

# %%
# !python pexels_scraper.py -k "563492ad6f91700001000001537b70e87e204efcb04961323e78fd5c" -c "cityscape" -d "cityscapes" -p 41 100 80
# Out:
# >> Page 41 out of 100 complete.
# >> Page 42 out of 100 complete.
# >> Page 43 out of 100 complete.
# >> Page 44 out of 100 complete.
# >> Page 45 out of 100 complete.
# >> Page 46 out of 100 complete.
# >> Page 47 out of 100 complete.
# >> Page 48 out of 100 complete.
# >> Page 49 out of 100 complete.
# >> Page 50 out of 100 complete.
# >> Page 51 out of 100 complete.
# >> Page 52 out of 100 complete.
# >> Page 53 out of 100 complete.
# >> Page 54 out of 100 complete.
# >> Page 55 out of 100 complete.
# >> Page 56 out of 100 complete.
# >> Page 57 out of 100 complete.
# >> Page 58 out of 100 complete.
# >> Page 59 out of 100 complete.
# >> Page 60 out of 100 complete.
# >> Page 61 out of 100 complete.
# >> Page 62 out of 100 complete.
# >> Page 63 out of 100 complete.
# >> Page 64 out of 100 complete.
# >> Page 65 out of 100 complete.
# >> Page 66 out of 100 complete.
# >> Page 67 out of 100 complete.
# >> Page 68 out of 100 complete.
# >> Page 69 out of 100 complete.
# ...
